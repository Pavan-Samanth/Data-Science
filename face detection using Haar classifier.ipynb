# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import os

# %% [markdown]
# This is file from my disk

# %%
img = cv2.imread('Stylish-Baby-Girl-Names-With-Their-Meanings.jpg')

# %%
image_gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
plt.imshow(image_gray,cmap='gray')

# %%
def convertToRGB(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %% [markdown]
# loading the Haar classifier from my system

# %%
haar_cascade_face = cv2.CascadeClassifier(r'C:\Users\pavan samanth\.anaconda\dlib-19.17.0\dlib\opencv\haarcascade_frontalface_default.xml')

# %%
faces_rects = haar_cascade_face.detectMultiScale(image_gray, scaleFactor = 1.2, minNeighbors = 5)

# %%
print('Faces found: ', len(faces_rects))
# Out:
# Faces found:  1

# %%
for (x,y,w,h) in faces_rects:
    cv2.rectangle(img,(x,y),(x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(convertToRGB(img))

# %% [markdown]
# # Generalised Function

# %%
def detect_faces(cascade,img,scaleFactor = 1.1):
     # create a copy of the image to prevent any changes to the original one.
    image_copy = img.copy()

    #convert the test image to gray scale as opencv face detector expects gray images
    gray_image = cv2.cvtColor(image_copy, cv2.COLOR_BGR2GRAY)

    # Applying the haar classifier to detect faces
    faces_rect = cascade.detectMultiScale(gray_image, scaleFactor=scaleFactor, minNeighbors=5)
    for (x, y, w, h) in faces_rect:
        cv2.rectangle(image_copy, (x, y), (x+w, y+h), (0, 255, 0), 15)

    return image_copy

# %% [markdown]
# This is also image from my local disk

# %%
test_image2 = cv2.imread('IMG_6662.jpg')
test_image2_gray = cv2.cvtColor(test_image2,cv2.COLOR_BGR2GRAY)
plt.imshow(test_image2_gray,cmap='gray')

# %%
faces = detect_faces(haar_cascade_face,test_image2)
plt.imshow(convertToRGB(faces))

# %%
test_image3 = cv2.imread('IMG_6671.jpg')
test_image3_gray = cv2.cvtColor(test_image3,cv2.COLOR_BGR2GRAY)
plt.imshow(test_image3_gray,cmap='gray')

# %%
faces = detect_faces(haar_cascade_face,test_image3)
plt.imshow(convertToRGB(faces))
